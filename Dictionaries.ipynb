# %%
x = {}
type(x)
# Out:
# dict

# %%
file_counts = {"jpg":10, "txt":14, "csv":2, "py":23}
print(file_counts)
# Out:
# {'jpg': 10, 'txt': 14, 'csv': 2, 'py': 23}

# %%
file_counts["txt"]
# Out:
# 14

# %%
"jpg" in file_counts
# Out:
# True

# %%
"html" in file_counts
# Out:
# False

# %%
file_counts["cfg"] = 8
print(file_counts)         #add file
# Out:
# {'jpg': 10, 'txt': 14, 'csv': 2, 'py': 23, 'cfg': 8}

# %%
file_counts["csv"] = 17
print(file_counts)         #replace 'csv' file count number
# Out:
# {'jpg': 10, 'txt': 14, 'csv': 17, 'py': 23, 'cfg': 8}

# %%
del file_counts["cfg"]
print(file_counts)         #del elements from dictionary
# Out:
# {'jpg': 10, 'txt': 14, 'csv': 17, 'py': 23}
