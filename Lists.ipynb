# %%
x = ["Now", "we", "are", "cooking!"]
type(x)
# Out:
# list

# %%
print(x)
# Out:
# ['Now', 'we', 'are', 'cooking!']

# %%
len(x)
# Out:
# 4

# %%
"are" in x
# Out:
# True

# %%
"Today" in x
# Out:
# False

# %%
print(x[0])
# Out:
# Now

# %%
print(x[3])
# Out:
# cooking!

# %%
x[1:3]
# Out:
# ['we', 'are']

# %%
x[:2]
# Out:
# ['Now', 'we']

# %%
x[2:]
# Out:
# ['are', 'cooking!']
